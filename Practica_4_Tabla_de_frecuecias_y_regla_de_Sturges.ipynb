# %% [markdown]
# <a href="https://colab.research.google.com/github/nahives/Practica-4.-Tabla-de-frecuecias-y-regla-de-Sturges/blob/main/Practica_4_Tabla_de_frecuecias_y_regla_de_Sturges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import *

# %%
#lista de calificciones del grupo a pobabilidad y estadistica
grupoa= {70,70,65,95,45,80,73,20,100,96}
print(grupoa)
# Out:
# {96, 65, 100, 70, 73, 45, 80, 20, 95}

# %%
# la funcion type nos devuelve el tipo de dato de la variale
type(grupoa)
# Out:
# set

# %%
promedio= sum(grupoa)/ len(grupoa)
print(promedio)
# Out:
# 71.55555555555556

# %%
# utilizar la funcion mean que esta en la libreria statistics para sacar el promedio
promedio2= mean(grupoa)
print(promedio2)
# Out:
# 71.55555555555556

# %%
# determinar el valor de la media con la fn median
mediana= median(grupoa)
print(mediana)
# Out:
# 73

# %%
# deteminar el valor de la moda con la fn mode
moda= mode(grupoa)
print(moda)
# Out:
# 96

# %% [markdown]
# ## EJEMPLO 2. TIEMPO DE 100 METROS DE U GRUPO DE 12 ALUMNOS.

# %%
#DEFINIMOS UNA VARIABLE LLAMADA TIEMPOS100MTS DE TIPO LISTA , QUE CONTIENEN LOS TIEMPOS QUE TARDAD LOS 10 ALMUNOS P;ARA CORRER LOS 100MTS
tiempos100mts=[15,10,17.20,14.69,13.27,22.15,18.71,19.15,20.65,15.10,17.20]
print(tiempos100mts)
# Out:
# [15, 10, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("el tiempo promedio de los corredores es=>", mean(tiempos100mts))
# Out:
# el tiempo promedio de los corredores es=> 16.64727272727273

# %%
mediana= median(tiempos100mts)
print("la media de los tiempos de los corredores es =>",mediana)
# Out:
# la media de los tiempos de los corredores es => 17.2

# %%
moda= mode(tiempos100mts)
print("la moda de los tiempos es=>",moda)
# Out:
# la moda de los tiempos es=> 17.2

# %%
multimodas=multimode(tiempos100mts)
print("la  moda de los tiempos es =>", multimodas)
# Out:
# la  moda de los tiempos es => [17.2]

# %% [markdown]
# ## Nueva sección

# %% [markdown]
# ## Ejemplo 3: Histogramas de 2 grupos

# %%
import random

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio= round (random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [67.77, 97.93, 61.07, 74.69, 90.47, 70.8, 66.07, 55.26, 50.73, 57.35, 72.91, 66.03, 56.01, 51.93, 57.16, 99.72, 59.44, 55.7, 65.9, 88.44, 74.9, 96.13, 71.88, 70.89, 91.04, 65.47, 59.24, 97.85, 72.98, 66.6, 79.95, 51.7, 82.05, 59.4, 64.49, 87.31, 52.88, 76.83, 69.14, 89.88, 77.42, 82.13, 68.24, 55.91, 97.28, 89.99, 72.16, 86.64, 56.95, 97.72, 71.63, 77.29, 60.38, 69.75, 86.78, 59.25, 70.07, 92.39, 85.73, 58.04, 81.86, 86.97, 82.84, 99.26, 52.63, 91.37, 77.56, 54.28, 67.03, 97.55, 79.7, 95.72, 53.32, 68.77, 66.66, 76.85, 99.7, 84.43, 51.74, 65.27, 61.76, 86.28, 52.86, 83.15, 60.93, 55.43, 55.77, 52.17, 96.47, 52.4, 97.37, 73.91, 76.02, 86.66, 72.24, 96.86, 98.05, 75.88, 70.85, 66.97]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio2= round (random.uniform(50,100),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [76.0, 54.49, 99.49, 86.46, 94.18, 64.1, 87.19, 61.52, 84.94, 85.92, 61.0, 61.59, 64.63, 64.19, 85.81, 73.67, 73.86, 57.95, 89.14, 50.55, 70.03, 66.2, 66.24, 96.48, 75.5, 65.11, 72.37, 50.13, 75.54, 62.88, 62.43, 89.02, 78.56, 91.28, 82.4, 75.56, 67.46, 76.73, 92.37, 52.93, 63.4, 59.69, 83.08, 92.09, 70.51, 86.11, 97.69, 75.31, 90.52, 75.52, 88.42, 71.99, 94.76, 76.55, 68.21, 88.65, 94.77, 83.24, 96.45, 98.79, 91.39, 51.62, 89.02, 91.38, 72.84, 56.88, 55.86, 89.55, 91.59, 71.17, 67.51, 60.98, 88.24, 72.85, 94.69, 66.67, 50.7, 99.24, 89.78, 57.59, 63.95, 91.2, 86.71, 73.19, 63.0, 68.97, 53.48, 51.42, 87.14, 54.85, 73.18, 90.6, 94.97, 56.62, 57.31, 93.09, 72.12, 66.63, 60.43, 53.84]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("produccion diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'produccion diaria de la fabrica 2')

# %%
media= mean(fabrica1)
mediana= median(fabrica1)
moda= mode(fabrica1)

print("valores de la fabrica 1")
print("la media es=", media)
print("la mediana es=",mediana)
print("la moda es=",moda)
# Out:
# valores de la fabrica 1
# la media es= 73.6728
# la mediana es= 72.02
# la moda es= 67.77

# %%
media= mean(fabrica2)
mediana= median(fabrica2)
moda= mode(fabrica2)

print("valores de la fabrica 2")
print("la media es=", media)
print("la mediana es=",mediana)
print("la moda es=",moda)
# Out:
# valores de la fabrica 2
# la media es= 75.239
# la mediana es= 73.765
# la moda es= 89.02

# %%
# generar 2 subplot de 1 reglon por 2 columnas para esplegar los 2 histogramas,
# uno al lado de la otra
fig,(ax1, ax2) =plt.subplots(nrows=1, ncols=2)

# %%
fig,(ax1, ax2) =plt.subplots(nrows=1, ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#valor minimo , maximo, rango

media1= mean(fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)

# %%
plt.hist(fabrica1, bins=10, alpha=0.4, color= 'b', edgecolor= "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle= "dashed", linewidth= 2, label= 'Mediana')
plt.axvline(moda1, color='y' , linestyle ='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('frecuericial')
plt.title("production diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
media2= mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)

plt.hist(fabrica2, bins=10, alpha=0.4, color= 'b', edgecolor= "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle= "dashed", linewidth= 2, label= 'Mediana')
plt.axvline(moda2, color='y' , linestyle ='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('frecuericial')
plt.title("production diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ## Maximo, minimo y rango

# %%
maximo= max(fabrica1)
minimo= min(fabrica1)
rango=maximo-minimo
media=mean(fabrica1)
mediana= median(fabrica1)
moda= mode(fabrica1)
print("Estadistica descriptiva de la fabrica 1 \n", "media=", media, "\n mediana =",mediana,"\n moda =",moda,"\n maximo=",maximo, "\n minimo=",minimo,"\n rango=",rango)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media= 73.6728
#  mediana = 72.02
#  moda = 67.77
#  maximo= 99.72
#  minimo= 50.73
#  rango= 48.99

# %%
maximo2= max(fabrica2)
minimo2= min(fabrica2)
rango2=maximo-minimo
media2=mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)
print("Estadistica descriptiva de la fabrica 2 \n", "media=", media2, "\n mediana =",mediana2,"\n moda =",moda2,"\n maximo=",maximo2, "\n minimo=",minimo2,"\n rango=",rango2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media= 75.239
#  mediana = 73.765
#  moda = 89.02
#  maximo= 99.49
#  minimo= 50.13
#  rango= 48.99

# %% [markdown]
# ## DISPERCION DE LOS DATOS

# %%
desviacion_estandar_fabrica1= stdev(fabrica1)
print("la desviacion de la fabrica 1 es =", desviacion_estandar_fabrica1)
# Out:
# la desviacion de la fabrica 1 es = 14.94711377700144

# %%
desviacion_estandar_fabrica2= stdev(fabrica2)
print("la desviacion de la fabrica 2 es =", desviacion_estandar_fabrica2)
# Out:
# la desviacion de la fabrica 2 es = 14.450507418304198

# %%
plt.figure(figsize=(10,8))
plt.hist(fabrica1, bins=10, alpha=0.4, color= 'b', edgecolor= "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle= "dashed", linewidth= 2, label= f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y' , linestyle ='dashed', linewidth=2, label=f'Moda={moda1:.2f}')

plt.axvline(media1 - desviacion_estandar_fabrica1 , color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1 , color='black', linestyle='dashed', linewidth=2, label='Desv. Estandar')
plt.xlabel('Valor')
plt.ylabel('frecuericial')
plt.title("production diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(fabrica2, bins=10, alpha=0.4, color= 'b', edgecolor= "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media:.2f}')
plt.axvline(mediana2, color='r', linestyle= "dashed", linewidth= 2, label= f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y' , linestyle ='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2 , color='black', linestyle='dashed', linewidth=2, label='Desv. Estandar')
plt.axvline(media2 + desviacion_estandar_fabrica2 , color='black', linestyle='dashed', linewidth=2, label=f'Desv. Estandar={desviacion_estandar_fabrica2:.2f}')
plt.xlabel('Valor')
plt.xlabel('Valor')
plt.ylabel('frecuericial')
plt.title("production diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ## TABLAS DE FRECUENCIA

# %%
# generamos una lista  vacia que representa la edad de un grupo de personas
edades = []
for i in range(100):
       numero_aleatorio = random.randint(18,70)
       edades.append(numero_aleatorio)
print(edades)
# Out:
# [36, 67, 23, 26, 20, 60, 65, 47, 60, 67, 68, 41, 32, 57, 30, 46, 26, 51, 48, 18, 32, 34, 44, 60, 50, 61, 66, 65, 62, 35, 70, 46, 48, 45, 64, 57, 65, 56, 62, 40, 63, 68, 42, 37, 39, 51, 22, 26, 30, 48, 35, 30, 33, 45, 66, 58, 65, 43, 41, 64, 18, 23, 56, 43, 43, 54, 47, 57, 27, 62, 35, 58, 36, 55, 36, 24, 30, 20, 50, 37, 26, 51, 53, 45, 44, 43, 38, 19, 53, 25, 41, 60, 34, 26, 34, 55, 24, 63, 41, 69]

# %%
import pandas as pd

# %%
df_edades = pd.DataFrame(edades, columns=["edad"])
df_edades
# Out:
#     edad
# 0     36
# 1     67
# 2     23
# 3     26
# 4     20
# ..   ...
# 95    55
# 96    24
# 97    63
# 98    41
# 99    69
#
# [100 rows x 1 columns]

# %%
#calcular la tabla de ditibucion de frecuencias'
tabla_frecuencia= df_edades["edad"].value_counts().reset_index()
tabla_frecuencia.columns=["edad", "frecuencia"]
tabla_frecuencia
# Out:
#     edad  frecuencia
# 0     26           5
# 1     30           4
# 2     43           4
# 3     60           4
# 4     65           4
# 5     41           4
# 6     36           3
# 7     45           3
# 8     62           3
# 9     34           3
# 10    48           3
# 11    51           3
# 12    35           3
# 13    57           3
# 14    46           2
# 15    20           2
# 16    53           2
# 17    24           2
# 18    55           2
# 19    23           2
# 20    58           2
# 21    37           2
# 22    56           2
# 23    64           2
# 24    63           2
# 25    50           2
# 26    47           2
# 27    66           2
# 28    32           2
# 29    18           2
# 30    68           2
# 31    67           2
# 32    44           2
# 33    27           1
# 34    25           1
# 35    19           1
# 36    38           1
# 37    70           1
# 38    54           1
# 39    33           1
# 40    22           1
# 41    39           1
# ...

# %%
#calcular la tabla de ditibucion de frecuencias'
tabla_frecuencia= df_edades["edad"].value_counts().reset_index()
tabla_frecuencia.columns=["edad", "frecuencia"]
tabla_frecuencia= tabla_frecuencia.sort_values(by="edad")
tabla_frecuencia
# Out:
#     edad  frecuencia
# 29    18           2
# 35    19           1
# 15    20           2
# 40    22           1
# 19    23           2
# 17    24           2
# 34    25           1
# 0     26           5
# 33    27           1
# 1     30           4
# 28    32           2
# 39    33           1
# 9     34           3
# 12    35           3
# 6     36           3
# 21    37           2
# 36    38           1
# 41    39           1
# 44    40           1
# 5     41           4
# 43    42           1
# 2     43           4
# 32    44           2
# 7     45           3
# 14    46           2
# 26    47           2
# 10    48           3
# 25    50           2
# 11    51           3
# 16    53           2
# 38    54           1
# 18    55           2
# 22    56           2
# 13    57           3
# 20    58           2
# 3     60           4
# 42    61           1
# 8     62           3
# 24    63           2
# 23    64           2
# 4     65           4
# 27    66           2
# ...

# %%
tabla_frecuencia["Frec. Relativa"] = tabla_frecuencia["frecuencia"] / 100

# %%
tabla_frecuencia
# Out:
#     edad  frecuencia  Frec. Relativa
# 29    18           2            0.02
# 35    19           1            0.01
# 15    20           2            0.02
# 40    22           1            0.01
# 19    23           2            0.02
# 17    24           2            0.02
# 34    25           1            0.01
# 0     26           5            0.05
# 33    27           1            0.01
# 1     30           4            0.04
# 28    32           2            0.02
# 39    33           1            0.01
# 9     34           3            0.03
# 12    35           3            0.03
# 6     36           3            0.03
# 21    37           2            0.02
# 36    38           1            0.01
# 41    39           1            0.01
# 44    40           1            0.01
# 5     41           4            0.04
# 43    42           1            0.01
# 2     43           4            0.04
# 32    44           2            0.02
# 7     45           3            0.03
# ...

# %%
tabla_frecuencia["Frec. Porcentaul"] = tabla_frecuencia["frecuencia"] / 100*100

# %%
tabla_frecuencia
# Out:
#     edad  frecuencia  Frec. Relativa  Frec. Porcentaul
# 29    18           2            0.02               2.0
# 35    19           1            0.01               1.0
# 15    20           2            0.02               2.0
# 40    22           1            0.01               1.0
# 19    23           2            0.02               2.0
# 17    24           2            0.02               2.0
# 34    25           1            0.01               1.0
# 0     26           5            0.05               5.0
# 33    27           1            0.01               1.0
# 1     30           4            0.04               4.0
# 28    32           2            0.02               2.0
# 39    33           1            0.01               1.0
# 9     34           3            0.03               3.0
# 12    35           3            0.03               3.0
# 6     36           3            0.03               3.0
# 21    37           2            0.02               2.0
# ...

# %%
#frecuencia acumulada

tabla_frecuencia["Frec.acumulada"] = tabla_frecuencia["frecuencia"].cumsum()
tabla_frecuencia
# Out:
#     edad  frecuencia  Frec. Relativa  Frec. Porcentaul  Frec.acumulada
# 29    18           2            0.02               2.0               2
# 35    19           1            0.01               1.0               3
# 15    20           2            0.02               2.0               5
# 40    22           1            0.01               1.0               6
# 19    23           2            0.02               2.0               8
# 17    24           2            0.02               2.0              10
# 34    25           1            0.01               1.0              11
# 0     26           5            0.05               5.0              16
# 33    27           1            0.01               1.0              17
# 1     30           4            0.04               4.0              21
# 28    32           2            0.02               2.0              23
# 39    33           1            0.01               1.0              24
# ...

# %% [markdown]
# ## REGLA DE STURGES

# %%
import math

# %%
print (edades)
# Out:
# [36, 67, 23, 26, 20, 60, 65, 47, 60, 67, 68, 41, 32, 57, 30, 46, 26, 51, 48, 18, 32, 34, 44, 60, 50, 61, 66, 65, 62, 35, 70, 46, 48, 45, 64, 57, 65, 56, 62, 40, 63, 68, 42, 37, 39, 51, 22, 26, 30, 48, 35, 30, 33, 45, 66, 58, 65, 43, 41, 64, 18, 23, 56, 43, 43, 54, 47, 57, 27, 62, 35, 58, 36, 55, 36, 24, 30, 20, 50, 37, 26, 51, 53, 45, 44, 43, 38, 19, 53, 25, 41, 60, 34, 26, 34, 55, 24, 63, 41, 69]

# %%
df_edades_struges= pd.DataFrame({"edades":edades})
df_edades_struges
# Out:
#     edades
# 0       36
# 1       67
# 2       23
# 3       26
# 4       20
# ..     ...
# 95      55
# 96      24
# 97      63
# 98      41
# 99      69
#
# [100 rows x 1 columns]

# %%
# calcular el n umero de intervalos o clases utilizando la regla de sturges
n= len(edades)
k = int ( 1 + math.log2(n))

print("valor de n=",n,"k o numero de intrvalos o clases =", k)
# Out:
# valor de n= 100 k o numero de intrvalos o clases = 7

# %%
plt.hist(edades)
plt.title("histograma de edades basado en valores estandar matplotlib")
# Out:
# Text(0.5, 1.0, 'histograma de edades basado en valores estandar matplotlib')

# %%
tabla_frec_sturges= pd.cut(df_edades_struges["edades"], bins =  k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  edades
# 0  (40.286, 47.714]      18
# 1    (62.571, 70.0]      16
# 2  (32.857, 40.286]      15
# 3  (55.143, 62.571]      15
# 4  (47.714, 55.143]      13
# 5  (25.429, 32.857]      12
# 6  (17.948, 25.429]      11

# %%
tabla_frec_sturges.columns= ["clase", " frecuencia"]
tabla_frec_sturges
# Out:
#               clase   frecuencia
# 0  (40.286, 47.714]           18
# 1    (62.571, 70.0]           16
# 2  (32.857, 40.286]           15
# 3  (55.143, 62.571]           15
# 4  (47.714, 55.143]           13
# 5  (25.429, 32.857]           12
# 6  (17.948, 25.429]           11

# %%
# ordenar la tabla de frecuencias por la clase o el intervalo
tabla_frec_sturges.sort_values(by="clase")
tabla_frec_sturges
# Out:
#               clase   frecuencia
# 0  (40.286, 47.714]           18
# 1    (62.571, 70.0]           16
# 2  (32.857, 40.286]           15
# 3  (55.143, 62.571]           15
# 4  (47.714, 55.143]           13
# 5  (25.429, 32.857]           12
# 6  (17.948, 25.429]           11

# %%
tabla_frec_sturges["Frec. Relativa"] = tabla_frec_sturges[" frecuencia"] / n
tabla_frec_sturges["Frec. Porcentaul"] = tabla_frec_sturges[" frecuencia"] / n * 100
tabla_frec_sturges["Frec.acumulada"] = tabla_frec_sturges[" frecuencia"].cumsum()

# %%
tabla_frec_sturges
# Out:
#               clase   frecuencia  Frec. Relativa  Frec. Porcentaul  \
# 0  (40.286, 47.714]           18            0.18              18.0
# 1    (62.571, 70.0]           16            0.16              16.0
# 2  (32.857, 40.286]           15            0.15              15.0
# 3  (55.143, 62.571]           15            0.15              15.0
# 4  (47.714, 55.143]           13            0.13              13.0
# 5  (25.429, 32.857]           12            0.12              12.0
# 6  (17.948, 25.429]           11            0.11              11.0
#
#    Frec.acumulada
# 0              18
# 1              34
# 2              49
# 3              64
# 4              77
# 5              89
# 6             100

# %%
plt.hist(df_edades_struges["edades"], bins=k,alpha=0.5, rwidth=.95)
plt.title("histograma basado en la regla de sturges")
plt.xlabel("edades")
plt.xlabel(" frecuencia")
# Out:
# Text(0.5, 0, ' frecuencia')
